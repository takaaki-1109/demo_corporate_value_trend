# %%
# ライブラリの読み込み
import pandas as pd
import time
import yfinance as yf
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename = 'nikkei.csv'
df = pd.read_csv(filename, encoding='shift-jis')
df
# Out:
#       コード    銘柄名               社名   業種
# 0    4151  協和キリン         協和キリン(株)  医薬品
# 1    4502     武田        武田薬品工業(株)  医薬品
# 2    4503  アステラス       アステラス製薬(株)  医薬品
# 3    4506  大日本住友       大日本住友製薬(株)  医薬品
# 4    4507    塩野義         塩野義製薬(株)  医薬品
# ..    ...    ...              ...  ...
# 220  9501   東電ＨＤ  東京電力ホールディングス(株)   電力
# 221  9502    中部電          中部電力(株)   電力
# 222  9503    関西電          関西電力(株)   電力
# 223  9531    東ガス          東京瓦斯(株)   ガス
# 224  9532    大ガス          大阪瓦斯(株)   ガス
#
# [225 rows x 4 columns]

# %%
def get_data(days, tickers):
    horizonData = pd.DataFrame()
    for company in tickers.keys():
        try:
            tkr = yf.Ticker(tickers[company])
            hist = tkr.history(period=f'{days}d')
            hist.index = hist.index.strftime('%d %B %Y')
            hist = hist[['Close']]
            hist.columns = [company]
            hist = hist.T
            hist.index.name = 'Name'
            horizonData = pd.concat([horizonData, hist])
        except Exception:
            pass
    return horizonData

# %%
#　取得期間を指定する
days = 15
tickers = {}
names = df['銘柄名'][:5]
i = 0
for name in names:
    code = df[df['銘柄名']==name]['コード'][i]
    stockCode = str(code) + '.T'
    ticker = {
        name: stockCode
    }
    tickers.update(ticker)
    i += 1
    
ymin, ymax = 6000, 8000
    
horizonData = get_data(days, tickers)

companies = ['武田','アステラス']

selectData = horizonData.loc[companies]

# %%
# !pip install altair
# Out:
# Requirement already satisfied: altair in /Users/nakadakyota/opt/anaconda3/lib/python3.9/site-packages (4.2.0)
# Requirement already satisfied: jinja2 in /Users/nakadakyota/opt/anaconda3/lib/python3.9/site-packages (from altair) (2.11.3)
# Requirement already satisfied: numpy in /Users/nakadakyota/opt/anaconda3/lib/python3.9/site-packages (from altair) (1.20.3)
# Requirement already satisfied: toolz in /Users/nakadakyota/opt/anaconda3/lib/python3.9/site-packages (from altair) (0.11.1)
# Requirement already satisfied: jsonschema>=3.0 in /Users/nakadakyota/opt/anaconda3/lib/python3.9/site-packages (from altair) (3.2.0)
# Requirement already satisfied: entrypoints in /Users/nakadakyota/opt/anaconda3/lib/python3.9/site-packages (from altair) (0.3)
# Requirement already satisfied: pandas>=0.18 in /Users/nakadakyota/opt/anaconda3/lib/python3.9/site-packages (from altair) (1.3.4)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/nakadakyota/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/nakadakyota/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair) (21.2.0)
# Requirement already satisfied: setuptools in /Users/nakadakyota/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair) (58.0.4)
# Requirement already satisfied: six>=1.11.0 in /Users/nakadakyota/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/nakadakyota/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.18->altair) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/nakadakyota/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.18->altair) (2021.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/nakadakyota/opt/anaconda3/lib/python3.9/site-packages (from jinja2->altair) (1.1.1)

# %%
import altair as alt

# %%
verticalData = selectData.T.reset_index()
verticalData = pd.melt(verticalData, id_vars=['Date']).rename(
    columns={'Date': '日付', 'Name': '銘柄', 'value': '株価（円）'}
)

chart = (
    alt.Chart(verticalData)
    .mark_line(opacity=0.8, clip=True)
    .encode(
        x="日付:T",
        y=alt.Y("株価（円）:Q", stack=None, scale=alt.Scale(domain=[ymin, ymax])),
        color="銘柄:N"
    )
)
    
chart
# Out:
# alt.Chart(...)

# %%
tickers
# Out:
# {'協和キリン': '4151.T',
#  '武田': '4502.T',
#  'アステラス': '4503.T',
#  '大日本住友': '4506.T',
#  '塩野義': '4507.T',
#  '中外薬': '4519.T',
#  'エーザイ': '4523.T',
#  '第一三共': '4568.T',
#  '大塚ＨＤ': '4578.T',
#  '日清紡ＨＤ': '3105.T',
#  'ミネベア': '6479.T',
#  '日立': '6501.T',
#  '三菱電': '6503.T',
#  '富士電機': '6504.T',
#  '安川電': '6506.T',
#  'オムロン': '6645.T',
#  'ＧＳユアサ': '6674.T',
#  'ＮＥＣ': '6701.T',
#  '富士通': '6702.T',
#  'ＯＫＩ': '6703.T',
#  'エプソン': '6724.T',
#  'パナソニック': '6752.T',
#  'シャープ': '6753.T',
#  'ソニーＧ': '6758.T',
#  'ＴＤＫ': '6762.T',
#  'アルプスアル': '6770.T',
#  '横河電': '6841.T',
#  'アドテスト': '6857.T',
#  'デンソー': '6902.T',
#  'カシオ': '6952.T',
#  'ファナック': '6954.T',
#  '京セラ': '6971.T',
#  '太陽誘電': '6976.T',
#  'スクリン': '7735.T',
#  'キヤノン': '7751.T',
#  'リコー': '7752.T',
#  '東エレク': '8035.T',
#  '日産自': '7201.T',
#  'いすゞ': '7202.T',
#  'トヨタ': '7203.T',
#  '日野自': '7205.T',
#  '三菱自': '7211.T',
#  'マツダ': '7261.T',
#  'ホンダ': '7267.T',
#  'スズキ': '7269.T',
#  'ＳＵＢＡＲＵ': '7270.T',
#  'ヤマハ発': '7272.T',
#  'テルモ': '4543.T',
#  'コニカミノル': '4902.T',
#  'ニコン': '7731.T',
#  'オリンパス': '7733.T',
#  'シチズン': '7762.T',
#  'スカパーＪ': '9412.T',
#  'ＮＴＴ': '9432.T',
#  'ＫＤＤＩ': '9433.T',
#  'ＳＢ': '9434.T',
#  'ＮＴＴデータ': '9613.T',
#  'ソフトバンク': '9984.T',
#  'コンコルディ': '7186.T',
#  '新生銀': '8303.T',
#  'あおぞら銀': '8304.T',
#  '三菱ＵＦＪ': '8306.T',
#  'りそなＨＤ': '8308.T',
#  '三井住友トラ': '8309.T',
#  '三井住友ＦＧ': '8316.T',
#  '千葉銀': '8331.T',
#  'ふくおかＦＧ': '8354.T',
#  '静岡銀': '8355.T',
#  'みずほＦＧ': '8411.T',
#  'クレセゾン': '8253.T',
#  '日本取引所': '8697.T',
#  '大和': '8601.T',
#  '野村': '8604.T',
#  '松井': '8628.T',
#  'ＳＯＭＰＯ': '8630.T',
#  'ＭＳ＆ＡＤ': '8725.T',
#  '第一生命ＨＤ': '8750.T',
#  '東京海上': '8766.T',
#  'Ｔ＆Ｄ': '8795.T',
#  '日水': '1332.T',
#  'マルハニチロ': '1333.T',
#  '日清粉Ｇ': '2002.T',
#  '明治ＨＤ': '2269.T',
#  '日ハム': '2282.T',
#  'サッポロＨＤ': '2501.T',
#  'アサヒ': '2502.T',
#  'キリンＨＤ': '2503.T',
#  '宝ＨＬＤ': '2531.T',
#  'キッコマン': '2801.T',
#  '味の素': '2802.T',
#  'ニチレイ': '2871.T',
#  'ＪＴ': '2914.T',
#  'Ｊフロント': '3086.T',
#  '三越伊勢丹': '3099.T',
#  'セブン＆アイ': '3382.T',
#  '高島屋': '8233.T',
#  '丸井Ｇ': '8252.T',
#  'イオン': '8267.T',
#  'ファストリ': '9983.T',
#  'エムスリー': '2413.T',
#  'ディーエヌエ': '2432.T',
#  'ネクソン': '3659.T',
#  '電通グループ': '4324.T',
#  'ＺＨＤ': '4689.T',
#  'トレンド': '4704.T',
#  'サイバー': '4751.T',
#  '楽天グループ': '4755.T',
#  'リクルート': '6098.T',
#  '日本郵政': '6178.T',
#  '東宝': '9602.T',
#  'セコム': '9735.T',
#  'コナミＨＤ': '9766.T',
#  'ＩＮＰＥＸ': '1605.T',
#  '東洋紡': '3101.T',
#  'ユニチカ': '3103.T',
#  '帝人': '3401.T',
#  '東レ': '3402.T',
#  '王子ＨＤ': '3861.T',
#  '日本紙': '3863.T',
#  'クラレ': '3405.T',
#  '旭化成': '3407.T',
#  '昭電工': '4004.T',
#  '住友化': '4005.T',
#  '日産化': '4021.T',
#  '東ソー': '4042.T',
#  'トクヤマ': '4043.T',
#  'デンカ': '4061.T',
#  '信越化': '4063.T',
#  '三井化学': '4183.T',
#  '三菱ケミＨＤ': '4188.T',
#  '宇部興': '4208.T',
#  '花王': '4452.T',
#  'ＤＩＣ': '4631.T',
#  '富士フイルム': '4901.T',
#  '資生堂': '4911.T',
#  '日東電': '6988.T',
#  '出光興産': '5019.T',
#  'ＥＮＥＯＳ': '5020.T',
#  '浜ゴム': '5101.T',
#  'ブリヂストン': '5108.T',
#  'ＡＧＣ': '5201.T',
#  '板硝子': '5202.T',
#  '日電硝': '5214.T',
#  '住友大阪': '5232.T',
#  '太平洋セメ': '5233.T',
#  '東海カ': '5301.T',
#  'ＴＯＴＯ': '5332.T',
#  'ガイシ': '5333.T',
#  '日本製鉄': '5401.T',
#  '神戸鋼': '5406.T',
#  'ＪＦＥ': '5411.T',
#  '大平金': '5541.T',
#  'ＳＵＭＣＯ': '3436.T',
#  '日軽金ＨＤ': '5703.T',
#  '三井金': '5706.T',
#  '東邦鉛': '5707.T',
#  '三菱マ': '5711.T',
#  '住友鉱': '5713.T',
#  'ＤＯＷＡ': '5714.T',
#  '古河電': '5801.T',
#  '住友電': '5802.T',
#  'フジクラ': '5803.T',
#  '洋缶ＨＤ': '5901.T',
#  '双日': '2768.T',
#  '伊藤忠': '8001.T',
#  '丸紅': '8002.T',
#  '豊田通商': '8015.T',
#  '三井物': '8031.T',
#  '住友商': '8053.T',
#  '三菱商': '8058.T',
#  'コムシスＨＤ': '1721.T',
#  '大成建': '1801.T',
#  '大林組': '1802.T',
#  '清水建': '1803.T',
#  '長谷工': '1808.T',
#  '鹿島': '1812.T',
#  'ハウス': '1925.T',
#  '積ハウス': '1928.T',
#  '日揮ＨＤ': '1963.T',
#  '日製鋼': '5631.T',
#  'オークマ': '6103.T',
#  'アマダ': '6113.T',
#  'コマツ': '6301.T',
#  '住友重': '6302.T',
#  '日立建機': '6305.T',
#  'クボタ': '6326.T',
#  '荏原': '6361.T',
#  'ダイキン': '6367.T',
#  '日精工': '6471.T',
#  'ＮＴＮ': '6472.T',
#  'ジェイテクト': '6473.T',
#  '日立造': '7004.T',
#  '三菱重': '7011.T',
#  'ＩＨＩ': '7013.T',
#  '三井Ｅ＆Ｓ': '7003.T',
#  '川重': '7012.T',
#  'バンナムＨＤ': '7832.T',
#  '凸版': '7911.T',
#  '大日印': '7912.T',
#  'ヤマハ': '7951.T',
#  '東急不ＨＤ': '3289.T',
#  '三井不': '8801.T',
#  '菱地所': '8802.T',
#  '東建物': '8804.T',
#  '住友不': '8830.T',
#  '東武': '9001.T',
#  '東急': '9005.T',
#  '小田急': '9007.T',
#  '京王': '9008.T',
#  '京成': '9009.T',
#  'ＪＲ東日本': '9020.T',
#  'ＪＲ西日本': '9021.T',
#  'ＪＲ東海': '9022.T',
#  '日通': '9062.T',
#  'ヤマトＨＤ': '9064.T',
#  '郵船': '9101.T',
#  '商船三井': '9104.T',
#  '川崎汽': '9107.T',
#  'ＡＮＡＨＤ': '9202.T',
#  '三菱倉': '9301.T',
#  '東電ＨＤ': '9501.T',
#  '中部電': '9502.T',
#  '関西電': '9503.T',
#  '東ガス': '9531.T',
#  '大ガス': '9532.T'}

# %%
industries = {}
kinds = df['業種'][:5]
kinds
j = 0
for kind in kinds:
    name = df[df['業種']==kind]['コード'][j]
    stockCode = str(code) + '.T'
    ticker = {
        kind: stockCode
    }
    industries.update(ticker)
    j += 1
industries
# Out:
# {'医薬品': '4507.T'}
